# %%
with open('climate_vocab.txt') as f:
    climate_vocab = f.read().lower().splitlines()
    
print(climate_vocab)
# Out:
# ['carbondioxide', 'greenhousegas', 'emissions', 'global', 'warming', 'fossil', 'fuels', 'sea-level', 'sea', 'temperature', 'renewableenergy', 'unfcc', 'cop', 'paris', 'intendednationallydeterminedcontribution', 'ipcc', 'intergovernmental', 'ppm', 'methane', 'pre-industrial', 'mitigation', 'fracking', 'climatechange', 'weather', 'heat', 'atmosphere', 'earth', 'preventativemeasures', 'preventative', 'carbon', 'ecosystem', 'energy', 'fuel', 'gas', 'oil', 'thermal', 'geosphere', 'biology', 'biofuel', 'biosphere', 'climate', 'weather', 'heat', 'atmosphere', 'adapt', 'life', 'earth', 'sun', 'sky', 'prevent', 'measures', 'preventative', 'innovation', 'carbon', 'ecosystem', 'energy', 'fuel', 'greenhouse', 'oil', 'carbon', 'waste', 'thermal', 'mitigation', 'efficiency', 'emissions', 'water', 'hydrogen', 'wave', 'gas', 'global', 'warming', 'temperature', 'geosphere', 'fossil', 'evaporation', 'biology', 'alternative', 'vapor', 'vulnerable', 'vulnerability']

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} datetime
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - datetime
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import pandas as pd
import datetime as dt
import dask
import glob
import json
import numpy as np
from edgar import Company, TXTML
from edgar import Edgar
import nltk
from nltk.corpus import stopwords
from textblob import Word
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

# %%
def get_edgar(ll, n):
    filinglist = []
    for el in ll:
        company = Company(el[0], el[1])
        tree = company.get_all_filings(filing_type = "10-K")
        docs = Company.get_documents(tree, no_of_documents=n, as_documents=True)
        texts = Company.get_documents(tree, no_of_documents=n, as_documents=False)
        if n<2:
            docs=[docs]
            texts=[texts]
        for i in range(n):
            date = docs[i].content['Filing Date']
            dateStr = str(date)
            year = date[:4]
            text = TXTML.parse_full_10K(texts[i])
            filinglist.append([el[0],el[1],date,year, text])
    df = pd.DataFrame(filinglist, columns=['Company','CIK','Filing_Date','Year','TEXT'])
    return df

tech_companies = [
    ['Alphabet Inc.','0001652044'],
    ['Apple Inc.', '0000320193'],
    ['Microsoft Corp','0000789019'],
    ['INTERNATIONAL BUSINESS MACHINES CORP', '0000051143'],
    ['INTEL CORP', "50863"]
]
# ['Dell Technologies Inc', '0001571996'],

tech_companiesDF = get_edgar(tech_companies,5)
tech_companiesDF
# Out:
#                                  Company         CIK Filing_Date  Year  \
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 20                            INTEL CORP       50863  2020-01-24  2020
# 21                            INTEL CORP       50863  2019-02-01  2019
# 22                            INTEL CORP       50863  2018-02-16  2018
# 23                            INTEL CORP       50863  2017-02-17  2017
# 24                            INTEL CORP       50863  2016-02-12  2016
#
#                                                  TEXT
# 0   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 1   \n\nAmendment No. 1 to Form 10-K\n\n \n\n    \...
# 2   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 3   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 4   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 5   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 6   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 7   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 8   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 9   \n\nForm 10-K\n\n \nTable of Contents\n\n  \n ...
# 10  \n\n\n\n\n\n\n\n\n\n\nmsft-10k_20200630.htm\n\...
# 11  \n\n\n\n\nmsft-10k_20190630.htm\n\n\n\n\n\n \n...
# 12  \n\n\n\n\nmsft-10k_20180630.htm\n\n\n\n\n\n \n...
# 13  \n\n\n\n\nmsft-10k_20170630.htm\n\n\n\n\n\n \n...
# 14  \n\n10-K\n\n \nTable of Contents\n\n\n\n UNITE...
# 15  \n\n\n\n      \n      \n      \n      \n      ...
# 16  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 17  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 18  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 19  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 20  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 21  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 22  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 23  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 24  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nUNITED...

# %%
#stopwords
stop = set(stopwords.words('english'))

def clean_text(DF): 
    #lowercase
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

    #remove punctuation
    DF['TEXT'] = DF['TEXT'].str.replace('[^\w\s]','').replace('/_/g', "")

    #remove stopwords
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

    #remove numbers
    DF['TEXT'] = DF['TEXT'].str.replace('\d+', '')

    #remove non-english words
    nltk.download('words')
    words = set(nltk.corpus.words.words())

    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in str(x).split() if x.lower() in words or not x.isalpha()))
    
    return DF


tech_companiesDF = clean_text(tech_companiesDF)
tech_companiesDF
# Out:
# [nltk_data] Downloading package words to /users/asumpon/nltk_data...
# [nltk_data]   Package words is already up-to-date!
#                                  Company         CIK Filing_Date  Year  \
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 20                            INTEL CORP       50863  2020-01-24  2020
# 21                            INTEL CORP       50863  2019-02-01  2019
# 22                            INTEL CORP       50863  2018-02-16  2018
# 23                            INTEL CORP       50863  2017-02-17  2017
# 24                            INTEL CORP       50863  2016-02-12  2016
#
#                                                  TEXT
# 0   document united exchange _____________________...
# 1   amendment form k united exchange commission fo...
# 2   document united exchange _____________________...
# 3   document united exchange _____________________...
# 4   document united exchange _____________________...
# 5   document united exchange form k mark one annua...
# 6   document united exchange form k mark one annua...
# 7   document united exchange form k mark one annua...
# 8   document united exchange form k mark one annua...
# 9   form k table contents united exchange commissi...
# 10  msftk_htm false united exchange commission for...
# 11  msftk_htm united exchange commission form k an...
# 12  msftk_htm united exchange commission form k an...
# 13  msftk_htm united exchange commission form k an...
# 14  k table contents united exchange commission fo...
# 15  capital stock par value per exchange form sect...
# 16  click rapidly navigate document united exchang...
# 17  click rapidly navigate document united exchang...
# 18  click rapidly navigate document united exchang...
# 19  click rapidly navigate document united exchang...
# 20  document intctrading_day united exchange form ...
# 21  document united exchange form report pursuant ...
# 22  document united exchange form report pursuant ...
# 23  document united exchange form report pursuant ...
# 24  k united exchange form report pursuant section...

# %%
# tech_companiesDF['TEXT'][0]

# %%
#remove frequent words
def remove_freq(DF):
    freq = pd.Series(' '.join(DF['TEXT']).split()).value_counts()[:10]
    freq

    freq = list(freq.index)
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
    DF['TEXT'].head()
    return DF

remove_freq(tech_companiesDF)
tech_companiesDF
# Out:
#                                  Company         CIK Filing_Date  Year  \
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 20                            INTEL CORP       50863  2020-01-24  2020
# 21                            INTEL CORP       50863  2019-02-01  2019
# 22                            INTEL CORP       50863  2018-02-16  2018
# 23                            INTEL CORP       50863  2017-02-17  2017
# 24                            INTEL CORP       50863  2016-02-12  2016
#
#                                                  TEXT
# 0   document united exchange _____________________...
# 1   amendment form k united exchange commission fo...
# 2   document united exchange _____________________...
# 3   document united exchange _____________________...
# 4   document united exchange _____________________...
# 5   document united exchange form k mark one annua...
# 6   document united exchange form k mark one annua...
# 7   document united exchange form k mark one annua...
# 8   document united exchange form k mark one annua...
# 9   form k table contents united exchange commissi...
# 10  msftk_htm false united exchange commission for...
# 11  msftk_htm united exchange commission form k an...
# 12  msftk_htm united exchange commission form k an...
# 13  msftk_htm united exchange commission form k an...
# 14  k table contents united exchange commission fo...
# 15  capital par value per exchange form section ex...
# 16  click rapidly navigate document united exchang...
# 17  click rapidly navigate document united exchang...
# 18  click rapidly navigate document united exchang...
# 19  click rapidly navigate document united exchang...
# 20  document intctrading_day united exchange form ...
# 21  document united exchange form report pursuant ...
# 22  document united exchange form report pursuant ...
# 23  document united exchange form report pursuant ...
# 24  k united exchange form report pursuant section...

# %%
tech_companies = tech_companiesDF[['Company', 'CIK', 'Filing_Date', 'Year','TEXT']].sort_values(by='Filing_Date', ascending=True)
tech_companies
# Out:
#                                  Company         CIK Filing_Date  Year  \
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 24                            INTEL CORP       50863  2016-02-12  2016
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 23                            INTEL CORP       50863  2017-02-17  2017
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 22                            INTEL CORP       50863  2018-02-16  2018
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 21                            INTEL CORP       50863  2019-02-01  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 20                            INTEL CORP       50863  2020-01-24  2020
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
#
#                                                  TEXT
# 9   form k table contents united exchange commissi...
# 24  k united exchange form report pursuant section...
# 19  click rapidly navigate document united exchang...
# 14  k table contents united exchange commission fo...
# 8   document united exchange form k mark one annua...
# 4   document united exchange _____________________...
# 23  document united exchange form report pursuant ...
# 18  click rapidly navigate document united exchang...
# 13  msftk_htm united exchange commission form k an...
# 7   document united exchange form k mark one annua...
# 3   document united exchange _____________________...
# 22  document united exchange form report pursuant ...
# 17  click rapidly navigate document united exchang...
# 12  msftk_htm united exchange commission form k an...
# 6   document united exchange form k mark one annua...
# 21  document united exchange form report pursuant ...
# 2   document united exchange _____________________...
# 1   amendment form k united exchange commission fo...
# 16  click rapidly navigate document united exchang...
# 11  msftk_htm united exchange commission form k an...
# 5   document united exchange form k mark one annua...
# 20  document intctrading_day united exchange form ...
# 0   document united exchange _____________________...
# 15  capital par value per exchange form section ex...
# 10  msftk_htm false united exchange commission for...

# %%
#Create frequency of special words found in documents
freqList = []
for text in tech_companiesDF['TEXT']:
    wordlist = text.split()
    clean_words = []
    for word in wordlist:
        if word in climate_vocab:
            clean_words.append(Word(re.sub("[^a-zA-Z]+", "", word)).lemmatize())
            
    count = Counter(clean_words)
    total = 0
    for w, frequency in count.items():
        total = total + frequency
    print(total)
    freqList.append(total)
     
#     print(count.most_common(200))
#     wc = WordCloud(background_color="white",width=1000,height=1000, max_words=100,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(count)
#     plt.imshow(wc)
#     plt.show()
# Out:
# 77
# 3
# 72
# 64
# 54
# 52
# 51
# 47
# 44
# 40
# 107
# 85
# 93
# 87
# 87
# 74
# 86
# 88
# 85
# 94
# 189
# 169
# 121
# 95
# 117

# %%
tech_companiesDF['Frequency'] = freqList
tech_companiesDF
# Out:
#                                  Company         CIK Filing_Date  Year  \
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 20                            INTEL CORP       50863  2020-01-24  2020
# 21                            INTEL CORP       50863  2019-02-01  2019
# 22                            INTEL CORP       50863  2018-02-16  2018
# 23                            INTEL CORP       50863  2017-02-17  2017
# 24                            INTEL CORP       50863  2016-02-12  2016
#
#                                                  TEXT  Frequency
# 0   document united exchange _____________________...         77
# 1   amendment form k united exchange commission fo...          3
# 2   document united exchange _____________________...         72
# 3   document united exchange _____________________...         64
# 4   document united exchange _____________________...         54
# 5   document united exchange form k mark one annua...         52
# 6   document united exchange form k mark one annua...         51
# 7   document united exchange form k mark one annua...         47
# 8   document united exchange form k mark one annua...         44
# 9   form k table contents united exchange commissi...         40
# 10  msftk_htm false united exchange commission for...        107
# 11  msftk_htm united exchange commission form k an...         85
# 12  msftk_htm united exchange commission form k an...         93
# 13  msftk_htm united exchange commission form k an...         87
# 14  k table contents united exchange commission fo...         87
# 15  capital par value per exchange form section ex...         74
# 16  click rapidly navigate document united exchang...         86
# 17  click rapidly navigate document united exchang...         88
# 18  click rapidly navigate document united exchang...         85
# 19  click rapidly navigate document united exchang...         94
# 20  document intctrading_day united exchange form ...        189
# 21  document united exchange form report pursuant ...        169
# 22  document united exchange form report pursuant ...        121
# 23  document united exchange form report pursuant ...         95
# 24  k united exchange form report pursuant section...        117

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
tech_companies = tech_companiesDF[['Company', 'CIK', 'Filing_Date', 'Year','TEXT','Frequency']].sort_values(by='Filing_Date', ascending=True)

# %%
plt.scatter(tech_companiesDF['Year'], tech_companiesDF['Frequency'])

# %%
colors = np.random.rand(25)
plt.scatter(tech_companiesDF['Year'], tech_companiesDF['Frequency'], c=colors, alpha=0.5)
plt.show()

# %%
groups = tech_companiesDF.groupby('Company')
#https://stackoverflow.com/questions/21654635/scatter-plots-in-pandas-pyplot-how-to-plot-by-category
#^This seems helpful
tech_companiesDF
# Out:
#                                  Company         CIK Filing_Date  Year  \
# 0                          Alphabet Inc.  0001652044  2020-02-04  2020
# 1                          Alphabet Inc.  0001652044  2019-02-06  2019
# 2                          Alphabet Inc.  0001652044  2019-02-05  2019
# 3                          Alphabet Inc.  0001652044  2018-02-06  2018
# 4                          Alphabet Inc.  0001652044  2017-02-03  2017
# 5                             Apple Inc.  0000320193  2019-10-31  2019
# 6                             Apple Inc.  0000320193  2018-11-05  2018
# 7                             Apple Inc.  0000320193  2017-11-03  2017
# 8                             Apple Inc.  0000320193  2016-10-26  2016
# 9                             Apple Inc.  0000320193  2015-10-28  2015
# 10                        Microsoft Corp  0000789019  2020-07-30  2020
# 11                        Microsoft Corp  0000789019  2019-08-01  2019
# 12                        Microsoft Corp  0000789019  2018-08-03  2018
# 13                        Microsoft Corp  0000789019  2017-08-02  2017
# 14                        Microsoft Corp  0000789019  2016-07-28  2016
# 15  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2020-02-25  2020
# 16  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2019-02-26  2019
# 17  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2018-02-27  2018
# 18  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2017-02-28  2017
# 19  INTERNATIONAL BUSINESS MACHINES CORP  0000051143  2016-02-23  2016
# 20                            INTEL CORP       50863  2020-01-24  2020
# 21                            INTEL CORP       50863  2019-02-01  2019
# 22                            INTEL CORP       50863  2018-02-16  2018
# 23                            INTEL CORP       50863  2017-02-17  2017
# 24                            INTEL CORP       50863  2016-02-12  2016
#
#                                                  TEXT  Frequency
# 0   document united exchange _____________________...         77
# 1   amendment form k united exchange commission fo...          3
# 2   document united exchange _____________________...         72
# 3   document united exchange _____________________...         64
# 4   document united exchange _____________________...         54
# 5   document united exchange form k mark one annua...         52
# 6   document united exchange form k mark one annua...         51
# 7   document united exchange form k mark one annua...         47
# 8   document united exchange form k mark one annua...         44
# 9   form k table contents united exchange commissi...         40
# 10  msftk_htm false united exchange commission for...        107
# 11  msftk_htm united exchange commission form k an...         85
# 12  msftk_htm united exchange commission form k an...         93
# 13  msftk_htm united exchange commission form k an...         87
# 14  k table contents united exchange commission fo...         87
# 15  capital par value per exchange form section ex...         74
# 16  click rapidly navigate document united exchang...         86
# 17  click rapidly navigate document united exchang...         88
# 18  click rapidly navigate document united exchang...         85
# 19  click rapidly navigate document united exchang...         94
# 20  document intctrading_day united exchange form ...        189
# 21  document united exchange form report pursuant ...        169
# 22  document united exchange form report pursuant ...        121
# 23  document united exchange form report pursuant ...         95
# 24  k united exchange form report pursuant section...        117
