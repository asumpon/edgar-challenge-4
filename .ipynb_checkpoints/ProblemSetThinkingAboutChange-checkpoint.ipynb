# %% [markdown]
# # Problem Set: Thinking About Change

# %% [markdown]
# ## Get Word Lists for each Sector

# %%
def getWordList(file):
    word_list = []
    with open(file) as f:
        word_list = f.read().lower().splitlines()
    print(word_list)
    return word_list

# %%
general_list = getWordList('general_list.txt')
tech_list = getWordList('tech_list.txt')
energy_list = getWordList('energy_list.txt')
cd_list = getWordList('cd_list.txt')
# Out:
# ['emissions', 'pollution', 'warming', 'environment', 'ecosystem', 'greenhouse', 'sea-level', 'conference of paris', 'weather', 'atmosphere', 'climate']
# ['solar', 'reusable', 'renewable', 'nuclear', 'carbon', 'neutral', 'greenhouse', 'energy efficient', 'carbon emissions', 'environment', 'electricity']
# ['oil', 'gas', 'emission-free', 'emissionless', 'fossil', 'fracking', 'climate-related', 'ecosystem', 'low-carbon', 'sustainability', 'petroleum']
# ['carbon', 'footprint', 'recycle', 'preventative', 'climate fund', 'biosphere', 'landfills', 'environmental', 'clean power', 'reduce', 'deforestation']

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} datetime
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - datetime
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import pandas as pd
import datetime as dt
import dask
import glob
import json
import numpy as np
from edgar import Company, TXTML
from edgar import Edgar
import nltk
from nltk.corpus import stopwords
from textblob import Word
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

# %%
def get_edgar(ll, n,file_type):
    filinglist = []
    for el in ll:
        company = Company(el[0], el[1])
        tree = company.get_all_filings(filing_type = file_type)
        docs = Company.get_documents(tree, no_of_documents=n, as_documents=True)
        texts = Company.get_documents(tree, no_of_documents=n, as_documents=False)
        if n<2:
            docs=[docs]
            texts=[texts]
        for i in range(n):
            date = docs[i].content['Filing Date']
            dateStr = str(date)
            year = date[:4]
            text = TXTML.parse_full_10K(texts[i])
            filinglist.append([el[0],el[1],file_type,date,year,text])
    df = pd.DataFrame(filinglist, columns=['Company','CIK','Filing_Type','Filing_Date','Year','TEXT'])
    return df

# %% [markdown]
# ## Requesting Company Data

# %%
tech_companies = [
    ['Alphabet Inc.','0001652044'],
    ['Apple Inc.', '0000320193'],
    ['Microsoft Corp','0000789019'],
    ['IBM Corp', '0000051143'],
    ['INTEL CORP', "50863"]
]

energy_companies = [
    ['EXXON MOBIL CORP','0000034088'],
    ['CHEVRON CORP', '0000093410'],
    ['MARATHON OIL CORP','0000101778'],
    ['Phillips 66', '0001534701'],
    ['Energy Transfer LP', '0001276187']
]

cd_companies = [
    ['MGM Resorts International','0000789570'],
    ['EBAY INC', '0001065088'],
    ['FORD MOTOR CO','0000037996'],
    ['Tesla, Inc.', '0001318605'],
    ['ETSY INC', '0001370637']
]

# %%
tech_companiesDF= get_edgar(tech_companies,5,"10-K")
tech_companiesDF
# Out:
#            Company         CIK Filing_Type Filing_Date  Year  \
# 0    Alphabet Inc.  0001652044        10-K  2020-02-04  2020
# 1    Alphabet Inc.  0001652044        10-K  2019-02-06  2019
# 2    Alphabet Inc.  0001652044        10-K  2019-02-05  2019
# 3    Alphabet Inc.  0001652044        10-K  2018-02-06  2018
# 4    Alphabet Inc.  0001652044        10-K  2017-02-03  2017
# 5       Apple Inc.  0000320193        10-K  2020-10-30  2020
# 6       Apple Inc.  0000320193        10-K  2019-10-31  2019
# 7       Apple Inc.  0000320193        10-K  2018-11-05  2018
# 8       Apple Inc.  0000320193        10-K  2017-11-03  2017
# 9       Apple Inc.  0000320193        10-K  2016-10-26  2016
# 10  Microsoft Corp  0000789019        10-K  2020-07-30  2020
# 11  Microsoft Corp  0000789019        10-K  2019-08-01  2019
# 12  Microsoft Corp  0000789019        10-K  2018-08-03  2018
# 13  Microsoft Corp  0000789019        10-K  2017-08-02  2017
# 14  Microsoft Corp  0000789019        10-K  2016-07-28  2016
# 15        IBM Corp  0000051143        10-K  2020-02-25  2020
# 16        IBM Corp  0000051143        10-K  2019-02-26  2019
# 17        IBM Corp  0000051143        10-K  2018-02-27  2018
# 18        IBM Corp  0000051143        10-K  2017-02-28  2017
# 19        IBM Corp  0000051143        10-K  2016-02-23  2016
# 20      INTEL CORP       50863        10-K  2020-01-24  2020
# 21      INTEL CORP       50863        10-K  2019-02-01  2019
# 22      INTEL CORP       50863        10-K  2018-02-16  2018
# 23      INTEL CORP       50863        10-K  2017-02-17  2017
# 24      INTEL CORP       50863        10-K  2016-02-12  2016
#
#                                                  TEXT
# 0   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 1   \n\nAmendment No. 1 to Form 10-K\n\n \n\n    \...
# 2   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 3   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 4   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 5   \n\n\n\n\naapl-20200926truetruetruetruetruetru...
# 6   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 7   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 8   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 9   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 10  \n\n\n\n\n\n\n\n\n\n\nmsft-10k_20200630.htm\n\...
# 11  \n\n\n\n\nmsft-10k_20190630.htm\n\n\n\n\n\n \n...
# 12  \n\n\n\n\nmsft-10k_20180630.htm\n\n\n\n\n\n \n...
# 13  \n\n\n\n\nmsft-10k_20170630.htm\n\n\n\n\n\n \n...
# 14  \n\n10-K\n\n \nTable of Contents\n\n\n\n UNITE...
# 15  \n\n\n\n      \n      \n      \n      \n      ...
# 16  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 17  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 18  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 19  \n\n\n\n\n\nQuickLinks\n -- Click here to rapi...
# 20  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 21  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 22  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 23  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 24  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nUNITED...

# %%
energy_companiesDF = get_edgar(energy_companies,5,"10-K")
energy_companiesDF
# Out:
#                Company         CIK Filing_Type Filing_Date  Year  \
# 0     EXXON MOBIL CORP  0000034088        10-K  2020-02-26  2020
# 1     EXXON MOBIL CORP  0000034088        10-K  2019-02-27  2019
# 2     EXXON MOBIL CORP  0000034088        10-K  2018-02-28  2018
# 3     EXXON MOBIL CORP  0000034088        10-K  2017-02-22  2017
# 4     EXXON MOBIL CORP  0000034088        10-K  2016-02-24  2016
# 5         CHEVRON CORP  0000093410        10-K  2020-02-21  2020
# 6         CHEVRON CORP  0000093410        10-K  2019-02-22  2019
# 7         CHEVRON CORP  0000093410        10-K  2018-02-22  2018
# 8         CHEVRON CORP  0000093410        10-K  2017-02-23  2017
# 9         CHEVRON CORP  0000093410        10-K  2016-02-25  2016
# 10   MARATHON OIL CORP  0000101778        10-K  2020-02-20  2020
# 11   MARATHON OIL CORP  0000101778        10-K  2019-02-21  2019
# 12   MARATHON OIL CORP  0000101778        10-K  2018-02-22  2018
# 13   MARATHON OIL CORP  0000101778        10-K  2017-02-24  2017
# 14   MARATHON OIL CORP  0000101778        10-K  2016-02-25  2016
# 15         Phillips 66  0001534701        10-K  2020-02-21  2020
# 16         Phillips 66  0001534701        10-K  2019-02-22  2019
# 17         Phillips 66  0001534701        10-K  2018-02-23  2018
# 18         Phillips 66  0001534701        10-K  2017-02-17  2017
# 19         Phillips 66  0001534701        10-K  2016-02-19  2016
# 20  Energy Transfer LP  0001276187        10-K  2020-02-21  2020
# 21  Energy Transfer LP  0001276187        10-K  2019-02-22  2019
# 22  Energy Transfer LP  0001276187        10-K  2018-02-23  2018
# 23  Energy Transfer LP  0001276187        10-K  2017-02-24  2017
# 24  Energy Transfer LP  0001276187        10-K  2016-02-29  2016
#
#                                                  TEXT
# 0   \n\n\n\n\n\n\n\n\n\n 0.086252036-04-012021-08-...
# 1   \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\n...
# 2   \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\n...
# 3   \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\n...
# 4   \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\n...
# 5   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 6   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 7   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 8   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 9   \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\n UNITE...
# 10  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 11  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 12  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 13  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 14  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nUNITED...
# 15  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 16  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 17  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 18  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 19  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nTable ...
# 20  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 21  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 22  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 23  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nTa...
# 24  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nTable ...

# %%
cd_companiesDF = get_edgar(cd_companies,5,"10-K")
cd_companiesDF
# Out:
#                       Company         CIK Filing_Type Filing_Date  Year  \
# 0   MGM Resorts International  0000789570        10-K  2020-02-27  2020
# 1   MGM Resorts International  0000789570        10-K  2019-02-27  2019
# 2   MGM Resorts International  0000789570        10-K  2018-03-01  2018
# 3   MGM Resorts International  0000789570        10-K  2017-03-01  2017
# 4   MGM Resorts International  0000789570        10-K  2016-02-29  2016
# 5                    EBAY INC  0001065088        10-K  2020-04-29  2020
# 6                    EBAY INC  0001065088        10-K  2020-01-31  2020
# 7                    EBAY INC  0001065088        10-K  2019-01-30  2019
# 8                    EBAY INC  0001065088        10-K  2018-02-05  2018
# 9                    EBAY INC  0001065088        10-K  2017-02-06  2017
# 10              FORD MOTOR CO  0000037996        10-K  2020-02-05  2020
# 11              FORD MOTOR CO  0000037996        10-K  2019-02-21  2019
# 12              FORD MOTOR CO  0000037996        10-K  2018-03-28  2018
# 13              FORD MOTOR CO  0000037996        10-K  2018-02-08  2018
# 14              FORD MOTOR CO  0000037996        10-K  2017-03-29  2017
# 15                Tesla, Inc.  0001318605        10-K  2020-04-28  2020
# 16                Tesla, Inc.  0001318605        10-K  2020-02-13  2020
# 17                Tesla, Inc.  0001318605        10-K  2019-02-19  2019
# 18                Tesla, Inc.  0001318605        10-K  2018-02-23  2018
# 19                Tesla, Inc.  0001318605        10-K  2017-03-01  2017
# 20                   ETSY INC  0001370637        10-K  2020-02-27  2020
# 21                   ETSY INC  0001370637        10-K  2019-02-28  2019
# 22                   ETSY INC  0001370637        10-K  2018-03-01  2018
# 23                   ETSY INC  0001370637        10-K  2017-02-28  2017
# 24                   ETSY INC  0001370637        10-K  2016-03-01  2016
#
#                                                  TEXT
# 0   \n\n\n\n\n\n\n\n\n\n\n\nmgm-10k_20191231.htm\n...
# 1   \n\n\n\n\nmgm-10k_20181231.htm\n\n\n\n\n\n \n ...
# 2   \n\n\n\n\nmgm-10k_20171231.htm\n\n\n\n\n\n \n ...
# 3   \n\n\n\n\nmgm-10k_20161231.htm\n\n\n\n\n\n \n ...
# 4   \n\n\n\n\nmgm-10k_20151231.htm\n\n\n\n\n\n \n ...
# 5   \n\n\n\n\n     \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 6   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 7   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 8   \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 9   \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n  ...
# 10  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 11  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 12  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 13  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 14  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\n U...
# 15  \n\n\n\n\n\n\n\n\n\n\n\ntsla-10ka_20191231.htm...
# 16  \n\n\n\n\n\n\n\n\n\n\n\ntsla-10k_20191231.htm\...
# 17  \n\n\n\n\ntsla-10k_20181231.htm\n\n\n\n\n\n \n...
# 18  \n\n\n\n\ntsla-10k_20171231.htm\n\n\n\n\n\n \n...
# 19  \n\n\n\n\ntsla-10k_20161231.htm\n\n\n\n\n\n \n...
# 20  \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...
# 21  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 22  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 23  \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...
# 24  \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nUNITED...

# %%
cd_companiesDF.index.name = 'Index'
tech_companiesDF.index.name = 'Index'
energy_companiesDF.index.name = 'Index'

# %%
cd_companiesDF['Index'] = cd_companiesDF.index
tech_companiesDF['Index'] = cd_companiesDF.index
energy_companiesDF['Index'] = cd_companiesDF.index

# %% [markdown]
# #### Combine all dataframes

# %%
tech_companiesDF['Sector'] = 'Technology'
energy_companiesDF['Sector']='Energy'
cd_companiesDF['Sector'] = 'Consumer Discretionary'

# %%
all_DF = pd.concat([tech_companiesDF, energy_companiesDF,cd_companiesDF], axis=0)
all_DF
# Out:
#              Company         CIK Filing_Type Filing_Date  Year  \
# Index
# 0      Alphabet Inc.  0001652044        10-K  2020-02-04  2020
# 1      Alphabet Inc.  0001652044        10-K  2019-02-06  2019
# 2      Alphabet Inc.  0001652044        10-K  2019-02-05  2019
# 3      Alphabet Inc.  0001652044        10-K  2018-02-06  2018
# 4      Alphabet Inc.  0001652044        10-K  2017-02-03  2017
# ...              ...         ...         ...         ...   ...
# 20          ETSY INC  0001370637        10-K  2020-02-27  2020
# 21          ETSY INC  0001370637        10-K  2019-02-28  2019
# 22          ETSY INC  0001370637        10-K  2018-03-01  2018
# 23          ETSY INC  0001370637        10-K  2017-02-28  2017
# 24          ETSY INC  0001370637        10-K  2016-03-01  2016
#
#                                                     TEXT  Index  \
# Index
# 0      \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...      0
# 1      \n\nAmendment No. 1 to Form 10-K\n\n \n\n    \...      1
# 2      \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...      2
# 3      \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...      3
# 4      \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...      4
# ...                                                  ...    ...
# 20     \n\n\n\n\n\n\n\n\t\n\t\t\n\t\tDocument\n\t\n\t...     20
# 21     \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...     21
# 22     \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...     22
# 23     \n\n\n\t\n\t\t\n\t\t\n\t\tDocument\n\t\n\t\nUN...     23
# 24     \n\n\n\t\n\t\t\n\t\t\n\t\t10-K\n\t\n\t\nUNITED...     24
#
#                        Sector
# Index
# 0                  Technology
# 1                  Technology
# 2                  Technology
# 3                  Technology
# 4                  Technology
# ...                       ...
# 20     Consumer Discretionary
# 21     Consumer Discretionary
# 22     Consumer Discretionary
# 23     Consumer Discretionary
# 24     Consumer Discretionary
#
# [75 rows x 8 columns]

# %% [markdown]
# ## Cleaning Text

# %% [markdown]
# ### Clean text function

# %%
#stopwords
nltk.download('words')
stop = set(stopwords.words('english'))

def clean_text(DF): 
    #lowercase
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

    #remove punctuation
    DF['TEXT'] = DF['TEXT'].str.replace('[^\w\s]','').replace('/_/g', "")

    #remove stopwords
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

    #remove numbers
    DF['TEXT'] = DF['TEXT'].str.replace('\d+', '')

    #remove non-english words
    words = set(nltk.corpus.words.words())

    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in str(x).split() if x.lower() in words or not x.isalpha()))
    
    return DF
# Out:
# [nltk_data] Downloading package words to /users/asumpon/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ### Clean dataframes

# %%
tech_companiesDF = clean_text(tech_companiesDF)
energy_companiesDF = clean_text(energy_companiesDF)
cd_companiesDF = clean_text(cd_companiesDF)
all_DF = clean_text(all_DF)

# %% [markdown]
# #### Remove frequent words function

# %%
#remove frequent words
def remove_freq(DF):
    freq = pd.Series(' '.join(DF['TEXT']).split()).value_counts()[:10]
    freq

    freq = list(freq.index)
    DF['TEXT'] = DF['TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
    DF['TEXT'].head()
    return DF

# %% [markdown]
# #### Remove frequent words from dataframe

# %%
remove_freq(tech_companiesDF)
remove_freq(energy_companiesDF)
remove_freq(cd_companiesDF)
remove_freq(all_DF)
# Out:
#              Company         CIK Filing_Type Filing_Date  Year  \
# Index
# 0      Alphabet Inc.  0001652044        10-K  2020-02-04  2020
# 1      Alphabet Inc.  0001652044        10-K  2019-02-06  2019
# 2      Alphabet Inc.  0001652044        10-K  2019-02-05  2019
# 3      Alphabet Inc.  0001652044        10-K  2018-02-06  2018
# 4      Alphabet Inc.  0001652044        10-K  2017-02-03  2017
# ...              ...         ...         ...         ...   ...
# 20          ETSY INC  0001370637        10-K  2020-02-27  2020
# 21          ETSY INC  0001370637        10-K  2019-02-28  2019
# 22          ETSY INC  0001370637        10-K  2018-03-01  2018
# 23          ETSY INC  0001370637        10-K  2017-02-28  2017
# 24          ETSY INC  0001370637        10-K  2016-03-01  2016
#
#                                                     TEXT  Index  \
# Index
# 0      document united exchange _____________________...      0
# 1      amendment form k united exchange commission fo...      1
# 2      document united exchange _____________________...      2
# 3      document united exchange _____________________...      3
# 4      document united exchange _____________________...      4
# ...                                                  ...    ...
# 20     document united exchange _____________________...     20
# 21     document united exchange _____________________...     21
# 22     document united exchange _____________________...     22
# 23     document united exchange _____________________...     23
# 24     k united exchange _________________________for...     24
#
#                        Sector
# Index
# 0                  Technology
# 1                  Technology
# 2                  Technology
# 3                  Technology
# 4                  Technology
# ...                       ...
# 20     Consumer Discretionary
# 21     Consumer Discretionary
# 22     Consumer Discretionary
# 23     Consumer Discretionary
# 24     Consumer Discretionary
#
# [75 rows x 8 columns]

# %% [markdown]
# ### Cleaned Data Frames

# %%
tech_companies = tech_companiesDF[['Company', 'CIK', 'Filing_Date', 'Year','Sector','TEXT']].sort_values(by='Filing_Date', ascending=True)
energy_companies = energy_companiesDF[['Company', 'CIK', 'Filing_Date', 'Year','Sector','TEXT']].sort_values(by='Filing_Date', ascending=True)
cd_companies = cd_companiesDF[['Company', 'CIK', 'Filing_Date', 'Year','Sector','TEXT']].sort_values(by='Filing_Date', ascending=True)
all_DF = all_DF[['Company', 'CIK', 'Filing_Date', 'Year','Sector','TEXT']].sort_values(by='Filing_Date', ascending=True)

# %%
all_DF
# Out:
#               Company         CIK Filing_Date  Year                  Sector  \
# Index
# 7            EBAY INC  0001065088  2019-01-30  2019  Consumer Discretionary
# 5            EBAY INC  0001065088  2020-04-29  2020  Consumer Discretionary
# 21           ETSY INC  0001370637  2019-02-28  2019  Consumer Discretionary
# 15        Tesla, Inc.  0001318605  2020-04-28  2020  Consumer Discretionary
# 20           ETSY INC  0001370637  2020-02-27  2020  Consumer Discretionary
# ...               ...         ...         ...   ...                     ...
# 11     Microsoft Corp  0000789019  2019-08-01  2019              Technology
# 16           IBM Corp  0000051143  2019-02-26  2019              Technology
# 1       Alphabet Inc.  0001652044  2019-02-06  2019              Technology
# 17           IBM Corp  0000051143  2018-02-27  2018              Technology
# 5          Apple Inc.  0000320193  2020-10-30  2020              Technology
#
#                                                     TEXT  Frequency
# Index
# 7      document accelerated united exchange commissio...          3
# 5      true large accelerated filer table contents un...          0
# 21     document united exchange _____________________...         10
# 15     tslaka_htm false large accelerated filer unite...          0
# 20     document united exchange _____________________...         13
# ...                                                  ...        ...
# 11     msftk_htm united exchange commission form k an...         19
# 16     click rapidly navigate document united exchang...         18
# 1      amendment form k united exchange commission fo...          0
# 17     click rapidly navigate document united exchang...         15
# 5      exchange form one annual report pursuant secti...          3
#
# [75 rows x 7 columns]

# %%
all_DF.rename(columns={'Unnamed: 0':'Index'},inplace=True) # Rename our index column

# %%
all_DF
# Out:
#                 Company         CIK Filing_Date  Year                  Sector  \
# Index
# 24           INTEL CORP       50863  2016-02-12  2016              Technology
# 19          Phillips 66  0001534701  2016-02-19  2016                  Energy
# 19             IBM Corp  0000051143  2016-02-23  2016              Technology
# 4      EXXON MOBIL CORP  0000034088  2016-02-24  2016                  Energy
# 9          CHEVRON CORP  0000093410  2016-02-25  2016                  Energy
# ...                 ...         ...         ...   ...                     ...
# 20             ETSY INC  0001370637  2020-02-27  2020  Consumer Discretionary
# 15          Tesla, Inc.  0001318605  2020-04-28  2020  Consumer Discretionary
# 5              EBAY INC  0001065088  2020-04-29  2020  Consumer Discretionary
# 10       Microsoft Corp  0000789019  2020-07-30  2020              Technology
# 5            Apple Inc.  0000320193  2020-10-30  2020              Technology
#
#                                                     TEXT
# Index
# 24     k united exchange form report pursuant section...
# 19     k table united exchange commission form k mark...
# 19     click rapidly navigate document united exchang...
# 4      united exchange commission form k annual repor...
# 9      k united exchange commission form k annual rep...
# ...                                                  ...
# 20     document united exchange _____________________...
# 15     tslaka_htm false large accelerated filer unite...
# 5      true large accelerated filer table contents un...
# 10     msftk_htm false united exchange commission for...
# 5      exchange form one annual report pursuant secti...
#
# [75 rows x 6 columns]

# %% [markdown]
# ## Frequency of Special Words

# %%
def special_freq(DF, sector_list):
    freqList = []
    for text in DF['TEXT']:
        wordlist = text.split()
        clean_words = []
        for word in wordlist:
            if word in general_list:
                clean_words.append(Word(re.sub("[^a-zA-Z]+", "", word)).lemmatize())
            if word in sector_list:
                clean_words.append(Word(re.sub("[^a-zA-Z]+", "", word)).lemmatize())
        count = Counter(clean_words)
        total = 0
        for w, frequency in count.items():
            total = total + frequency
        freqList.append(total)
    return freqList

# %%
tech_companiesDF['Frequency'] = special_freq(tech_companiesDF, tech_list)
energy_companiesDF['Frequency'] = special_freq(energy_companiesDF, energy_list)
cd_companiesDF['Frequency'] = special_freq(cd_companiesDF, cd_list)
all_DF['Frequency'] = special_freq(all_DF,[])

# %%
tech_companiesDF
# Out:
#               Company         CIK Filing_Type Filing_Date  Year  \
# Index
# 0       Alphabet Inc.  0001652044        10-K  2020-02-04  2020
# 1       Alphabet Inc.  0001652044        10-K  2019-02-06  2019
# 2       Alphabet Inc.  0001652044        10-K  2019-02-05  2019
# 3       Alphabet Inc.  0001652044        10-K  2018-02-06  2018
# 4       Alphabet Inc.  0001652044        10-K  2017-02-03  2017
# 5          Apple Inc.  0000320193        10-K  2020-10-30  2020
# 6          Apple Inc.  0000320193        10-K  2019-10-31  2019
# 7          Apple Inc.  0000320193        10-K  2018-11-05  2018
# 8          Apple Inc.  0000320193        10-K  2017-11-03  2017
# 9          Apple Inc.  0000320193        10-K  2016-10-26  2016
# 10     Microsoft Corp  0000789019        10-K  2020-07-30  2020
# 11     Microsoft Corp  0000789019        10-K  2019-08-01  2019
# 12     Microsoft Corp  0000789019        10-K  2018-08-03  2018
# 13     Microsoft Corp  0000789019        10-K  2017-08-02  2017
# 14     Microsoft Corp  0000789019        10-K  2016-07-28  2016
# 15           IBM Corp  0000051143        10-K  2020-02-25  2020
# 16           IBM Corp  0000051143        10-K  2019-02-26  2019
# 17           IBM Corp  0000051143        10-K  2018-02-27  2018
# 18           IBM Corp  0000051143        10-K  2017-02-28  2017
# 19           IBM Corp  0000051143        10-K  2016-02-23  2016
# 20         INTEL CORP       50863        10-K  2020-01-24  2020
# 21         INTEL CORP       50863        10-K  2019-02-01  2019
# 22         INTEL CORP       50863        10-K  2018-02-16  2018
# 23         INTEL CORP       50863        10-K  2017-02-17  2017
# 24         INTEL CORP       50863        10-K  2016-02-12  2016
#
#                                                     TEXT  Index      Sector  \
# Index
# 0      document united exchange _____________________...      0  Technology
# 1      amendment form k united exchange commission fo...      1  Technology
# 2      document united exchange _____________________...      2  Technology
# 3      document united exchange _____________________...      3  Technology
# 4      document united exchange _____________________...      4  Technology
# 5      exchange form one annual report pursuant secti...      5  Technology
# 6      document united exchange form k mark one annua...      6  Technology
# 7      document united exchange form k mark one annua...      7  Technology
# 8      document united exchange form k mark one annua...      8  Technology
# 9      document united exchange form k mark one annua...      9  Technology
# 10     msftk_htm false united exchange commission for...     10  Technology
# 11     msftk_htm united exchange commission form k an...     11  Technology
# 12     msftk_htm united exchange commission form k an...     12  Technology
# 13     msftk_htm united exchange commission form k an...     13  Technology
# 14     k table contents united exchange commission fo...     14  Technology
# 15     capital par value per exchange form section ex...     15  Technology
# 16     click rapidly navigate document united exchang...     16  Technology
# 17     click rapidly navigate document united exchang...     17  Technology
# 18     click rapidly navigate document united exchang...     18  Technology
# 19     click rapidly navigate document united exchang...     19  Technology
# 20     document intctrading_day united exchange form ...     20  Technology
# 21     document united exchange form report pursuant ...     21  Technology
# 22     document united exchange form report pursuant ...     22  Technology
# 23     document united exchange form report pursuant ...     23  Technology
# 24     k united exchange form report pursuant section...     24  Technology
#
#        Frequency
# Index
# 0             29
# 1              0
# 2             16
# 3             10
# 4              9
# 5              5
# 6              5
# 7              7
# 8              5
# 9              5
# 10            50
# 11            29
# 12            29
# 13            31
# 14            30
# 15            24
# 16            28
# 17            23
# 18            24
# 19            29
# 20            60
# 21            45
# 22            33
# 23            25
# 24            44

# %%
energy_companiesDF
# Out:
#                   Company         CIK Filing_Type Filing_Date  Year  \
# Index
# 0        EXXON MOBIL CORP  0000034088        10-K  2020-02-26  2020
# 1        EXXON MOBIL CORP  0000034088        10-K  2019-02-27  2019
# 2        EXXON MOBIL CORP  0000034088        10-K  2018-02-28  2018
# 3        EXXON MOBIL CORP  0000034088        10-K  2017-02-22  2017
# 4        EXXON MOBIL CORP  0000034088        10-K  2016-02-24  2016
# 5            CHEVRON CORP  0000093410        10-K  2020-02-21  2020
# 6            CHEVRON CORP  0000093410        10-K  2019-02-22  2019
# 7            CHEVRON CORP  0000093410        10-K  2018-02-22  2018
# 8            CHEVRON CORP  0000093410        10-K  2017-02-23  2017
# 9            CHEVRON CORP  0000093410        10-K  2016-02-25  2016
# 10      MARATHON OIL CORP  0000101778        10-K  2020-02-20  2020
# 11      MARATHON OIL CORP  0000101778        10-K  2019-02-21  2019
# 12      MARATHON OIL CORP  0000101778        10-K  2018-02-22  2018
# 13      MARATHON OIL CORP  0000101778        10-K  2017-02-24  2017
# 14      MARATHON OIL CORP  0000101778        10-K  2016-02-25  2016
# 15            Phillips 66  0001534701        10-K  2020-02-21  2020
# 16            Phillips 66  0001534701        10-K  2019-02-22  2019
# 17            Phillips 66  0001534701        10-K  2018-02-23  2018
# 18            Phillips 66  0001534701        10-K  2017-02-17  2017
# 19            Phillips 66  0001534701        10-K  2016-02-19  2016
# 20     Energy Transfer LP  0001276187        10-K  2020-02-21  2020
# 21     Energy Transfer LP  0001276187        10-K  2019-02-22  2019
# 22     Energy Transfer LP  0001276187        10-K  2018-02-23  2018
# 23     Energy Transfer LP  0001276187        10-K  2017-02-24  2017
# 24     Energy Transfer LP  0001276187        10-K  2016-02-29  2016
#
#                                                     TEXT  Index  Sector  \
# Index
# 0      united exchange commission form k annual repor...      0  Energy
# 1      united exchange commission form k annual repor...      1  Energy
# 2      united exchange commission form k annual repor...      2  Energy
# 3      united exchange commission form k annual repor...      3  Energy
# 4      united exchange commission form k annual repor...      4  Energy
# 5      document note beginning page finance lease end...      5  Energy
# 6      document united exchange commission form k ann...      6  Energy
# 7      document united exchange commission form k ann...      7  Energy
# 8      document united exchange commission form k ann...      8  Energy
# 9      k united exchange commission form k annual rep...      9  Energy
# 10     document mrommbtu_per_day mrobbls_per_day unit...     10  Energy
# 11     document united exchange form report pursuant ...     11  Energy
# 12     document united exchange form report pursuant ...     12  Energy
# 13     document united exchange form report pursuant ...     13  Energy
# 14     k united exchange form report pursuant section...     14  Energy
# 15     document return equity psxreporting_unit psxjo...     15  Energy
# 16     document table united exchange commission form...     16  Energy
# 17     document table united exchange commission form...     17  Energy
# 18     document table united exchange commission form...     18  Energy
# 19     k table united exchange commission form k mark...     19  Energy
# 20     document etemb_bls table exchange form k annua...     20  Energy
# 21     document table exchange form report pursuant s...     21  Energy
# 22     document table exchange form report pursuant s...     22  Energy
# 23     document table exchange form report pursuant s...     23  Energy
# 24     k table exchange form report pursuant section ...     24  Energy
#
#        Frequency
# Index
# 0             88
# 1             89
# 2             86
# 3             82
# 4             84
# 5             91
# 6             85
# 7             77
# 8             78
# 9             73
# 10            66
# 11            64
# 12            71
# 13            65
# 14            71
# 15           236
# 16           237
# 17           115
# 18           114
# 19           110
# 20           111
# 21           111
# 22           127
# 23           131
# 24           157

# %%
cd_companiesDF
# Out:
#                          Company         CIK Filing_Type Filing_Date  Year  \
# Index
# 0      MGM Resorts International  0000789570        10-K  2020-02-27  2020
# 1      MGM Resorts International  0000789570        10-K  2019-02-27  2019
# 2      MGM Resorts International  0000789570        10-K  2018-03-01  2018
# 3      MGM Resorts International  0000789570        10-K  2017-03-01  2017
# 4      MGM Resorts International  0000789570        10-K  2016-02-29  2016
# 5                       EBAY INC  0001065088        10-K  2020-04-29  2020
# 6                       EBAY INC  0001065088        10-K  2020-01-31  2020
# 7                       EBAY INC  0001065088        10-K  2019-01-30  2019
# 8                       EBAY INC  0001065088        10-K  2018-02-05  2018
# 9                       EBAY INC  0001065088        10-K  2017-02-06  2017
# 10                 FORD MOTOR CO  0000037996        10-K  2020-02-05  2020
# 11                 FORD MOTOR CO  0000037996        10-K  2019-02-21  2019
# 12                 FORD MOTOR CO  0000037996        10-K  2018-03-28  2018
# 13                 FORD MOTOR CO  0000037996        10-K  2018-02-08  2018
# 14                 FORD MOTOR CO  0000037996        10-K  2017-03-29  2017
# 15                   Tesla, Inc.  0001318605        10-K  2020-04-28  2020
# 16                   Tesla, Inc.  0001318605        10-K  2020-02-13  2020
# 17                   Tesla, Inc.  0001318605        10-K  2019-02-19  2019
# 18                   Tesla, Inc.  0001318605        10-K  2018-02-23  2018
# 19                   Tesla, Inc.  0001318605        10-K  2017-03-01  2017
# 20                      ETSY INC  0001370637        10-K  2020-02-27  2020
# 21                      ETSY INC  0001370637        10-K  2019-02-28  2019
# 22                      ETSY INC  0001370637        10-K  2018-03-01  2018
# 23                      ETSY INC  0001370637        10-K  2017-02-28  2017
# 24                      ETSY INC  0001370637        10-K  2016-03-01  2016
#
#                                                     TEXT  Index  \
# Index
# 0      mgmk_htm false large accelerated filer de leas...      0
# 1      mgmk_htm united exchange commission form k mar...      1
# 2      mgmk_htm united exchange commission form k mar...      2
# 3      mgmk_htm united exchange commission form k mar...      3
# 4      mgmk_htm united exchange commission form k mar...      4
# 5      true large accelerated filer table contents un...      5
# 6      document united exchange commission form k ann...      6
# 7      document accelerated united exchange commissio...      7
# 8      document accelerated united exchange commissio...      8
# 9      document united exchange commission form k rep...      9
# 10     document united exchange form k annual report ...     10
# 11     document united exchange form one report pursu...     11
# 12     document united exchange form mark one report ...     12
# 13     document united exchange form one report pursu...     13
# 14     document united exchange form mark one report ...     14
# 15     tslaka_htm false large accelerated filer unite...     15
# 16     tslak_htm false large accelerated filer true t...     16
# 17     tslak_htm united exchange commission form k ma...     17
# 18     tslak_htm united exchange commission form k ma...     18
# 19     tslak_htm united exchange commission form k ma...     19
# 20     document united exchange _____________________...     20
# 21     document united exchange _____________________...     21
# 22     document united exchange _____________________...     22
# 23     document united exchange _____________________...     23
# 24     k united exchange _________________________for...     24
#
#                        Sector  Frequency
# Index
# 0      Consumer Discretionary         48
# 1      Consumer Discretionary         47
# 2      Consumer Discretionary         51
# 3      Consumer Discretionary         45
# 4      Consumer Discretionary         63
# 5      Consumer Discretionary          6
# 6      Consumer Discretionary         38
# 7      Consumer Discretionary         41
# 8      Consumer Discretionary         38
# 9      Consumer Discretionary         33
# 10     Consumer Discretionary         55
# 11     Consumer Discretionary         47
# 12     Consumer Discretionary          0
# 13     Consumer Discretionary         48
# 14     Consumer Discretionary          0
# 15     Consumer Discretionary          1
# 16     Consumer Discretionary         43
# 17     Consumer Discretionary         45
# 18     Consumer Discretionary         36
# 19     Consumer Discretionary         39
# 20     Consumer Discretionary         69
# 21     Consumer Discretionary         56
# 22     Consumer Discretionary         28
# 23     Consumer Discretionary         31
# 24     Consumer Discretionary         42

# %%
all_DF
# Out:
#                 Company         CIK Filing_Date  Year                  Sector  \
# Index
# 24           INTEL CORP       50863  2016-02-12  2016              Technology
# 19          Phillips 66  0001534701  2016-02-19  2016                  Energy
# 19             IBM Corp  0000051143  2016-02-23  2016              Technology
# 4      EXXON MOBIL CORP  0000034088  2016-02-24  2016                  Energy
# 9          CHEVRON CORP  0000093410  2016-02-25  2016                  Energy
# ...                 ...         ...         ...   ...                     ...
# 20             ETSY INC  0001370637  2020-02-27  2020  Consumer Discretionary
# 15          Tesla, Inc.  0001318605  2020-04-28  2020  Consumer Discretionary
# 5              EBAY INC  0001065088  2020-04-29  2020  Consumer Discretionary
# 10       Microsoft Corp  0000789019  2020-07-30  2020              Technology
# 5            Apple Inc.  0000320193  2020-10-30  2020              Technology
#
#                                                     TEXT  Frequency
# Index
# 24     k united exchange form report pursuant section...         26
# 19     k table united exchange commission form k mark...         44
# 19     click rapidly navigate document united exchang...         20
# 4      united exchange commission form k annual repor...         41
# 9      k united exchange commission form k annual rep...         30
# ...                                                  ...        ...
# 20     document united exchange _____________________...         13
# 15     tslaka_htm false large accelerated filer unite...          0
# 5      true large accelerated filer table contents un...          0
# 10     msftk_htm false united exchange commission for...         29
# 5      exchange form one annual report pursuant secti...          3
#
# [75 rows x 7 columns]

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Plot Frequency for Entire Sector

# %%
fig, ax = plt.subplots()
ax.plot(tech_companiesDF.groupby('Year')['Frequency'].sum())
ax.plot(energy_companiesDF.groupby('Year')['Frequency'].sum())
ax.plot(cd_companiesDF.groupby('Year')['Frequency'].sum())
ax.legend(['Tech','Energy','Consumer Discretionary'],loc='center left', bbox_to_anchor=(1, 0.5),prop={'size': 9})
ax.set_title('Line Plot: Year vs Frequency')
# Out:
# Text(0.5, 1.0, 'Line Plot: Year vs Frequency')

# %%
plt.style.use('ggplot')
def visualizeFreqPerSector(DF, title, xMax):
    plt.plot(DF.groupby('Year')['Frequency'].sum())
    plt.xlim([2015,2021])
    plt.ylim([0,xMax])
    plt.title('Frequency of Special Words and Sector-specific words for '+ title + ' 2016-2020')
    plt.xlabel('Year')
    plt.ylabel('Frequency')
    plt.show()

# %%
visualizeFreqPerSector(tech_companiesDF,'Tech Sector',800)
visualizeFreqPerSector(energy_companiesDF,'Energy Sector',800)
visualizeFreqPerSector(cd_companiesDF,'Consumer Discretionary Sector',800)
visualizeFreqPerSector(all_DF,'ALL Sectors',800)

# %%
plt.style.use('ggplot')
def visualizeFreqPerCompany(DF, title,xMax):
    DF['Year'] = DF['Year'].astype(int)
    DF.sort_values(by='Year', inplace=True, ascending=True)
    df = pd.DataFrame(dict(x= DF['Year'], y = DF['Frequency'], label = DF['Company']))
    groups = df.groupby('label')

    fig, ax = plt.subplots()
    ax = plt.gca()
    ax.set_xlim([2015,2021])
    ax.set_ylim([0,xMax])
    ax.margins(0.05)
    for name, group in groups:
        ax.plot(group.x, group.y, marker='.', linestyle='', ms=9, label=name)

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={'size': 9})
    plt.title('Frequency of Special Words and Sector-specific words per '+ title)
    plt.xlabel('Year')
    plt.ylabel('Frequency')

    plt.show()

# %%
visualizeFreqPerCompany(tech_companiesDF,'Tech Companies 2016-2020',100)
visualizeFreqPerCompany(energy_companiesDF,'Energy Companies 2016-2020',250)
visualizeFreqPerCompany(cd_companiesDF,'Consumer Discretionary Companies 2016-2020',100)
visualizeFreqPerCompany(all_DF,'ALL Companies 2016-2020',100)

# %% [markdown]
# ### Streamgraph

# %%
import altair as alt
from vega_datasets import data

# %%
all_DF = all_DF.sort_values(by =['Sector'])
all_DF
# Out:
#               Company         CIK Filing_Date  Year                  Sector  \
# Index
# 7            EBAY INC  0001065088  2019-01-30  2019  Consumer Discretionary
# 5            EBAY INC  0001065088  2020-04-29  2020  Consumer Discretionary
# 21           ETSY INC  0001370637  2019-02-28  2019  Consumer Discretionary
# 15        Tesla, Inc.  0001318605  2020-04-28  2020  Consumer Discretionary
# 20           ETSY INC  0001370637  2020-02-27  2020  Consumer Discretionary
# ...               ...         ...         ...   ...                     ...
# 11     Microsoft Corp  0000789019  2019-08-01  2019              Technology
# 16           IBM Corp  0000051143  2019-02-26  2019              Technology
# 1       Alphabet Inc.  0001652044  2019-02-06  2019              Technology
# 17           IBM Corp  0000051143  2018-02-27  2018              Technology
# 5          Apple Inc.  0000320193  2020-10-30  2020              Technology
#
#                                                     TEXT  Frequency
# Index
# 7      document accelerated united exchange commissio...          3
# 5      true large accelerated filer table contents un...          0
# 21     document united exchange _____________________...         10
# 15     tslaka_htm false large accelerated filer unite...          0
# 20     document united exchange _____________________...         13
# ...                                                  ...        ...
# 11     msftk_htm united exchange commission form k an...         19
# 16     click rapidly navigate document united exchang...         18
# 1      amendment form k united exchange commission fo...          0
# 17     click rapidly navigate document united exchang...         15
# 5      exchange form one annual report pursuant secti...          3
#
# [75 rows x 7 columns]

# %%
import altair as alt
from vega_datasets import data

source = data.unemployment_across_industries.url

alt.Chart(source).mark_area().encode(
    alt.X('yearmonth(date):T',
        axis=alt.Axis(format='%Y', domain=False, tickSize=0)
    ),
    alt.Y('sum(count):Q', stack='center', axis=None),
    alt.Color('series:N',
        scale=alt.Scale(scheme='category20b')
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
json1 = all_DF.groupby('Sector')['Frequency'].sum().to_json()
json1
# Out:
# '{"Consumer Discretionary":233,"Energy":1193,"Technology":380}'

# %%
def getFrequency(DF):
    techDF = tech_companiesDF.groupby('Year')['Frequency'].sum()
    json1 = techDF.to_json()
    json_obj = json.loads(json1)
    return [json_obj['2016'], json_obj['2017'],json_obj['2018'],json_obj['2019'],json_obj['2020']]

# %%
techFreqList = getFrequency(tech_companiesDF)
energyFreqList = getFrequency(energy_companiesDF)
cdFreqList = getFrequency(cd_companiesDF)

# %%
df = pd.DataFrame({
    'Technology': techFreqList,
    'Energy': energyFreqList,
    'Consumer Discretionary': cdFreqList
 }, index=(2016,2017,2018,2019,2020))

# %%
ax = df.plot.area(title = 'Stacked Area Plot: Year vs Frequency',xlabel = 'Year', ylabel = 'Frequency', figsize=(12, 8))

# %%
json_obj = json.loads(json1)
df2 = pd.DataFrame({
    'Technology': techFreqList,
    'Energy': energyFreqList,
    'Consumer Discretionary': cdFreqList
 }, index=(2016,2017,2018,2019,2020))

# %%
df2.plot.pie(subplots=True, figsize=(20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x2aaadb5632b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2aaadb595af0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2aaadb5b8d60>],
#       dtype=object)

# %%
def jaccard(row, n=1):
    
    old=row['Story_1']
    new=row['Story_2']
    
    old_n_grams = [tuple(el) for el in TextBlob(old).ngrams(n)]
    new_n_grams = [tuple(el) for el in TextBlob(new).ngrams(n)]
        
    union = list(set(old_n_grams) | set(new_n_grams))
    intersection = list(set(old_n_grams) & set(new_n_grams))
    
    lu = len(union)
    li = len(intersection)
    
    return (li/lu,li,lu)

# %%
from textblob import Word
from textblob import TextBlob

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) # This suppresses a warning from scikit learn that they are going to update their code

# %%
# set1 = tech_companiesDF[['Index','Company','TEXT','Year']]
# set2 = energy_companiesDF[['Index','Company','TEXT','Year']]

# %%
def getSimilarity(DF1,DF2):
    set1 = DF1[['Index','Company','TEXT','Year']]
    set2 = DF2[['Index','Company','TEXT','Year']]

    set1['key']=1 
    set2['key']=1

    similarity = pd.merge(set1, set2, on ='key', suffixes=('_1', '_2')).drop("key", 1)
    similarity['Cosine_Similarity']=similarity.apply(lambda x: cosine(x),axis=1)
    return similarity

def get_cosine_sim(str1,str2): 
    vectors = [t for t in get_vectors([str1,str2])]
    return cosine_similarity(vectors)
    
def get_vectors(slist):
    text = [t for t in slist]
    vectorizer = CountVectorizer(text)
    vectorizer.fit(text)
    return vectorizer.transform(text).toarray()

def cosine(row):
    
    old=row['TEXT_1']
    new=row['TEXT_2']
    
    return get_cosine_sim(old,new)[0,1]

def visualizeSimilarity(metric,similarity, title):
    index = list(similarity['Year_1'].unique())
    columns = list(similarity['Year_2'].unique())
    df = pd.DataFrame(0, index=index, columns=columns)

    for i in df.index:
        sub = similarity[(similarity['Year_1']==i)]
        for col in df.columns:
            df.loc[i,col]=sub[sub['Year_2']==col][metric].iloc[0]

    plt.pcolor(df)
    plt.title("Cosine Similarity: " + title)
    plt.yticks(np.arange(0.1, len(df.index), 1), df.index)
    plt.xticks(np.arange(0.1, len(df.columns), 1), df.columns)
    plt.show()

# %% [markdown]
# ## Tech Similarity to other sectors

# %%
metric = 'Cosine_Similarity'
similarity_Tech_Energy = getSimilarity(tech_companiesDF,energy_companiesDF)
visualizeSimilarity(metric, similarity_Tech_Energy,'Tech vs Energy')

similarity_Tech_CD = getSimilarity(tech_companiesDF,cd_companiesDF)
visualizeSimilarity(metric, similarity_Tech_CD,'Tech vs Consumer Discretionary')
# Out:
# <ipython-input-48-da4b0e4922d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set1['key']=1
# <ipython-input-48-da4b0e4922d2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set2['key']=1

# %%
metric = 'Cosine_Similarity'
similarity_Energy_Tech = getSimilarity(energy_companiesDF,tech_companiesDF)
visualizeSimilarity(metric, similarity_Energy_Tech,'Energy vs Tech')

similarity_Energy_CD = getSimilarity(energy_companiesDF,cd_companiesDF)
visualizeSimilarity(metric, similarity_Energy_CD,'Energy vs Consumer Discretionary')

# %%
metric = 'Cosine_Similarity'
similarity_CD_Energy = getSimilarity(cd_companiesDF,energy_companiesDF)
visualizeSimilarity(metric, similarity_CD_Energy,'Consumer Discretionary vs Energy')

similarity_CD_Tech = getSimilarity(cd_companiesDF,tech_companiesDF)
visualizeSimilarity(metric, similarity_CD_Tech,'Consumer Discretionary vs Tech')
# Out:
# <ipython-input-48-da4b0e4922d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set1['key']=1
# <ipython-input-48-da4b0e4922d2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set2['key']=1
# <ipython-input-48-da4b0e4922d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set1['key']=1
# <ipython-input-48-da4b0e4922d2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   set2['key']=1

# %%
def jaccard(row, n=1):
    
    old=row['TEXT_1']
    new=row['TEXT_2']
    
    old_n_grams = [tuple(el) for el in TextBlob(old).ngrams(n)]
    new_n_grams = [tuple(el) for el in TextBlob(new).ngrams(n)]
        
    union = list(set(old_n_grams) | set(new_n_grams))
    intersection = list(set(old_n_grams) & set(new_n_grams))
    
    lu = len(union)
    li = len(intersection)
    
    return (li/lu,li,lu)

# %%
for i in [1,2]: # Add values to the list for the n-gram you're interested in
    similarity['Jaccard_Index_for_{}_grams'.format(i)]=similarity.apply(lambda x: jaccard(x,i)[0],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-dbee34b36efc> in <module>
#       1 for i in [1,2]: # Add values to the list for the n-gram you're interested in
# ----> 2     similarity['Jaccard_Index_for_{}_grams'.format(i)]=similarity.apply(lambda x: jaccard(x,i)[0],axis=1)
#
# NameError: name 'similarity' is not defined

# %%
similarity['Intersection']=similarity.apply(lambda x: jaccard(x)[1],axis=1)

# %%
similarity['Union']=similarity.apply(lambda x: jaccard(x)[2],axis=1)

# %%
similarity.head()

# %%
metric = 'Jaccard_Index_for_1_grams'

# %%
import numpy as np 
import matplotlib.pyplot as plt

index = list(similarity['Index_1'].unique())
columns = list(similarity['Index_2'].unique())
df = pd.DataFrame(0, index=index, columns=columns)

for i in df.index:
    sub = similarity[(similarity['Index_1']==i)]
    for col in df.columns:
        df.loc[i,col]=sub[sub['Index_2']==col][metric].iloc[0]
        
plt.pcolor(df)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.show()

# %%
similarity[['Company_1','Index_1','Company_2','Index_2',metric]].sort_values(by=metric,ascending=False)

# %%
similarity['Cosine_Similarity']=similarity.apply(lambda x: cosine(x),axis=1)

# %%
metric = 'Cosine_Similarity'
#metric = 'Jaccard_Index_for_1_grams'

# %%
import numpy as np 
import matplotlib.pyplot as plt

index = list(similarity['Year_1'].unique())
columns = list(similarity['Year_2'].unique())
df = pd.DataFrame(0, index=index, columns=columns)

for i in df.index:
    sub = similarity[(similarity['Year_1']==i)]
    for col in df.columns:
        df.loc[i,col]=sub[sub['Year_2']==col][metric].iloc[0]
        
plt.pcolor(df)
plt.title("Cosine Similarity: Tech vs Energy")
plt.yticks(np.arange(0.1, len(df.index), 1), df.index)
plt.xticks(np.arange(0.1, len(df.columns), 1), df.columns)
plt.show()

# %%
##
